# %%
import requests
api_keys='1fa58e46afa643f1ade53651242802'
city='madurai'
url=f"http://api.weatherapi.com/v1/current.json?key={api_keys}&q={city}"
response=requests.get(url)
data=response.json()
print(data)
# Out:
# {'location': {'name': 'Madurai', 'region': 'Tamil Nadu', 'country': 'India', 'lat': 9.93, 'lon': 78.12, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709136224, 'localtime': '2024-02-28 21:33'}, 'current': {'last_updated_epoch': 1709136000, 'last_updated': '2024-02-28 21:30', 'temp_c': 25.8, 'temp_f': 78.4, 'is_day': 0, 'condition': {'text': 'Clear ', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 12.3, 'wind_kph': 19.8, 'wind_degree': 73, 'wind_dir': 'ENE', 'pressure_mb': 1012.0, 'pressure_in': 29.89, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 64, 'cloud': 0, 'feelslike_c': 27.2, 'feelslike_f': 81.0, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 18.6, 'gust_kph': 30.0}}

# %%
type(data)
# Out:
# dict

# %%
print("city:",data['location']['name'])
print("state:",data['location']['region'])
print("country:",data['location']['country'])
print("temp in :",data['current']['temp_c'])
print("wind direction:",data['current']['wind_dir'])
print("wind_speed:",data['current']['wind_mph'])
print("humidity:",data['current']['humidity'])
print("feels_like:",data['current']['feelslike_c'])
# Out:
# city: Madurai
# state: Tamil Nadu
# country: India
# temp in : 32.0
# wind direction: NE
# wind_speed: 10.5
# humidity: 52
# feels_like: 32.0

# %%
import requests
api_keys='1fa58e46afa643f1ade53651242802'
city=input('enter any city')
url=f"http://api.weatherapi.com/v1/current.json?key={api_keys}&q={city}"
response=requests.get(url)
data=response.json()
print(data)
print("city:",data['location']['name'])
print("state:",data['location']['region'])
print("country:",data['location']['country'])
print("temp in :",data['current']['temp_c'])
print("wind direction:",data['current']['wind_dir'])
print("wind_speed:",data['current']['wind_mph'])
print("humidity:",data['current']['humidity'])
print("feels_like:",data['current']['feelslike_c'])
# Out:
# enter any cityvizag
# {'location': {'name': 'Vizag', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 17.7, 'lon': 83.3, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709102814, 'localtime': '2024-02-28 12:16'}, 'current': {'last_updated_epoch': 1709102700, 'last_updated': '2024-02-28 12:15', 'temp_c': 28.2, 'temp_f': 82.8, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 7.6, 'wind_kph': 12.2, 'wind_degree': 127, 'wind_dir': 'SE', 'pressure_mb': 1013.0, 'pressure_in': 29.9, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 56, 'cloud': 5, 'feelslike_c': 29.6, 'feelslike_f': 85.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 7.0, 'gust_mph': 8.7, 'gust_kph': 14.1}}
# city: Vizag
# state: Andhra Pradesh
# country: India
# temp in : 28.2
# wind direction: SE
# wind_speed: 7.6
# humidity: 56
# feels_like: 29.6

# %%
import requests
api_keys='1fa58e46afa643f1ade53651242802'
city=input('enter any city')
url=f"http://api.weatherapi.com/v1/current.json?key={api_keys}&q={city}"
response=requests.get(url)
data=response.json()
print(data)
if data['error']['code']==1006:
    print("no location found")
else:
    print("city:",data['location']['name'])
    print("state:",data['location']['region'])
    print("country:",data['location']['country'])
    print("temp in :",data['current']['temp_c'])
    print("wind direction:",data['current']['wind_dir'])
    print("wind_speed:",data['current']['wind_mph'])
    print("humidity:",data['current']['humidity'])
    print("feels like:",data['current']['feelslike_c'])
# Out:
# enter any citygiyyf
# {'error': {'code': 1006, 'message': 'No matching location found.'}}
# no location found

# %%
import requests
api_keys='1fa58e46afa643f1ade52'
city=input('enter any city')
url=f"http://api.weatherapi.com/v1/current.json?key={api_keys}&q={city}"
response=requests.get(url)
data=response.json()
if response.status_code==200:
    print("city:",data['location']['name'])
    print("state:",data['location']['region'])
    print("country:",data['location']['country'])
    print("temp in :",data['current']['temp_c'])
    print("wind direction:",data['current']['wind_dir'])
    print("wind_speed:",data['current']['wind_mph'])
    print("humidity:",data['current']['humidity'])
    print("feels_like:",data['current']['feelslike_c'])
else:
    print(data['error']['code'])
# Out:
# enter any cityooty
# 2008

# %%
import requests
api_keys='1fa58e46afa643f1ade52'
city=input('enter any city')
url=f"http://api.weatherapi.com/v1/current.json?key={api_keys}&q={city}"
response=requests.get(url)
data=response.json()
